# %%
file = open("avila-ts.txt", "r")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import joblib

# %%
df = pd.read_csv("avila-ts.txt",sep = ",", header=None)
df_tr = pd.read_csv("avila-tr.txt",sep = ",", header=None)

# %%
df.columns =['intercolumnar_distance', 'upper_margin', 'lower_margin', 'exploitation','row_number','modular_ratio',  'interlinear_spacing','weight','peak_number','diff','class']
df_tr.columns=['intercolumnar_distance', 'upper_margin', 'lower_margin', 'exploitation','row_number','modular_ratio',  'interlinear_spacing','weight','peak_number','diff','class']
df['class'].unique()
# Out:
# array(['W', 'A', 'I', 'E', 'F', 'Y', 'H', 'D', 'G', 'X', 'C', 'B'],
#       dtype=object)

# %% [markdown]
# Tout d'abord on explore les valeurs du dataset

# %%
df.describe()
# Out:
#        intercolumnar_distance  upper_margin  lower_margin  exploitation  \
# count            10437.000000  10437.000000  10437.000000  10437.000000
# mean                -0.000852      0.003396      0.005181      0.002616
# std                  1.008551      0.955257      0.992430      0.991443
# min                 -3.498799     -2.426761     -3.210528     -5.440122
# 25%                 -0.128929     -0.259834      0.064919     -0.526838
# 50%                  0.056229     -0.063555      0.217845      0.087408
# 75%                  0.204355      0.203385      0.356544      0.627208
# max                 11.819916     19.470188      7.458681      3.987152
#
#          row_number  modular_ratio  interlinear_spacing        weight  \
# count  10437.000000   10437.000000         10437.000000  10437.000000
# mean      -0.006365      -0.008886             0.002350     -0.010259
# std        1.007876       1.000360             0.966827      0.996431
# ...

# %% [markdown]
# On observe la répartition des valeurs, on voit qu'elle est clairement inégale

# %%
df['class'].value_counts().plot(kind='bar');

# %%
On

# %%
list_var = df.columns[:-1]
fig = plt.figure()

for i in list_var:
    fig, ax = plt.subplots(figsize=(10,8))
    ax = sns.boxplot(x='class',y=i,data=df,whis=150)
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr().abs(), vmax=1, vmin=0, annot=True,  cmap='YlGnBu')
plt.title('Correlation entre les différents attributs')
plt.show()

# %%
sns.pairplot(df[df['class'] != 'B'], hue='class')
